# %% [markdown]
# <a href="https://colab.research.google.com/github/HelenLit/imdb-reviews_nlp/blob/main/imdb_reviews.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Downloading the IMDB reviews plain text and tokenized datasets
#
# [IMDB Reviews](https://www.tensorflow.org/datasets/catalog/imdb_reviews) dataset from Tensorflow Datasets, there are two configurations:
#
# * `plain_text` - this is the default text
# * `subwords8k` - a pre-tokenized dataset (i.e. instead of sentences of type string, it will already gives the tokenized sequences).

# %%
import tensorflow_datasets as tfds

# Downloading the plain text default config
imdb_plaintext, info_plaintext = tfds.load("imdb_reviews", with_info=True, as_supervised=True)

# Downloading the subword encoded pretokenized dataset
imdb_subwords, info_subwords = tfds.load("imdb_reviews/subwords8k", with_info=True, as_supervised=True)
# Out:
# ...
# Dl Completed...: 0 url [00:00, ? url/s]
# Dl Size...: 0 MiB [00:00, ? MiB/s]
# ...
# Generating train examples...:   0%|          | 0/25000 [00:00<?, ? examples/s]
# Shuffling /root/tensorflow_datasets/imdb_reviews/plain_text/1.0.0.incompleteN7M54R/imdb_reviews-train.tfrecord…
# Generating test examples...:   0%|          | 0/25000 [00:00<?, ? examples/s]
# Shuffling /root/tensorflow_datasets/imdb_reviews/plain_text/1.0.0.incompleteN7M54R/imdb_reviews-test.tfrecord*…
# Generating unsupervised examples...:   0%|          | 0/50000 [00:00<?, ? examples/s]
# Shuffling /root/tensorflow_datasets/imdb_reviews/plain_text/1.0.0.incompleteN7M54R/imdb_reviews-unsupervised.t…
# Dataset imdb_reviews downloaded and prepared to /root/tensorflow_datasets/imdb_reviews/plain_text/1.0.0. Subsequent calls will reuse this data.
# ...

# %% [markdown]
# ## Comparing the two datasets
#
# The data types returned by the two datasets will be different. For the default, it will be strings. The description of the `text` key below and the sample sentences:

# %%
# Print description of features
info_plaintext.features
# Out:
# FeaturesDict({
#     'label': ClassLabel(shape=(), dtype=int64, num_classes=2),
#     'text': Text(shape=(), dtype=string),
# })

# %%
#2 training examples and the text feature
for example in imdb_plaintext['train'].take(2):
  print(example[0].numpy())
# Out:
# b"This was an absolutely terrible movie. Don't be lured in by Christopher Walken or Michael Ironside. Both are great actors, but this must simply be their worst role in history. Even their great acting could not redeem this movie's ridiculous storyline. This movie is an early nineties US propaganda piece. The most pathetic scenes were those when the Columbian rebels were making their cases for revolutions. Maria Conchita Alonso appeared phony, and her pseudo-love affair with Walken was nothing but a pathetic emotional plug in a movie that was devoid of any real meaning. I am disappointed that there are movies like this, ruining actor's like Christopher Walken's good name. I could barely sit through it."
# ...

# %% [markdown]
# For `subwords8k`, the dataset is already tokenized so the data type will be integers. The `text` features also include an `encoder` field and has a `vocab_size` of around 8k, hence the name.

# %%
# Printing description of features
info_subwords.features
# Out:
# FeaturesDict({
#     'label': ClassLabel(shape=(), dtype=int64, num_classes=2),
#     'text': Text(shape=(None,), dtype=int64, encoder=<SubwordTextEncoder vocab_size=8185>),
# })

# %% [markdown]
# As the result, there is no string sentences but a sequence of tokens:

# %%
# Taking 2 training examples and print its contents
for example in imdb_subwords['train'].take(2):
  print(example)
# Out:
# (<tf.Tensor: shape=(163,), dtype=int64, numpy=
# array([  62,   18,   41,  604,  927,   65,    3,  644, 7968,   21,   35,
#        5096,   36,   11,   43, 2948, 5240,  102,   50,  681, 7862, 1244,
#           3, 3266,   29,  122,  640,    2,   26,   14,  279,  438,   35,
#          79,  349,  384,   11, 1991,    3,  492,   79,  122,  188,  117,
#          33, 4047, 4531,   14,   65, 7968,    8, 1819, 3947,    3,   62,
#          27,    9,   41,  577, 5044, 2629, 2552, 7193, 7961, 3642,    3,
#          19,  107, 3903,  225,   85,  198,   72,    1, 1512,  738, 2347,
#         102, 6245,    8,   85,  308,   79, 6936, 7961,   23, 4981, 8044,
#           3, 6429, 7961, 1141, 1335, 1848, 4848,   55, 3601, 4217, 8050,
#           2,    5,   59, 3831, 1484, 8040, 7974,  174, 5773,   22, 5240,
#         102,   18,  247,   26,    4, 3903, 1612, 3902,  291,   11,    4,
#          27,   13,   18, 4092, 4008, 7961,    6,  119,  213, 2774,    3,
# ...

# %% [markdown]
# I can get the `encoder` object included in the download and use it to decode the sequences above. I will arrive at the same sentences provided in the `plain_text` config:

# %%
#The encoder
tokenizer_subwords = info_subwords.features['text'].encoder

#2 training examples and decoded text feature
for example in imdb_subwords['train'].take(2):
  print(tokenizer_subwords.decode(example[0]))
# Out:
# This was an absolutely terrible movie. Don't be lured in by Christopher Walken or Michael Ironside. Both are great actors, but this must simply be their worst role in history. Even their great acting could not redeem this movie's ridiculous storyline. This movie is an early nineties US propaganda piece. The most pathetic scenes were those when the Columbian rebels were making their cases for revolutions. Maria Conchita Alonso appeared phony, and her pseudo-love affair with Walken was nothing but a pathetic emotional plug in a movie that was devoid of any real meaning. I am disappointed that there are movies like this, ruining actor's like Christopher Walken's good name. I could barely sit through it.
# ...

# %% [markdown]
# ## Subword Text Encoding
#
# From previous labs, I had the number of tokens in the sequence which was the same as the number of words in the text (i.e. word tokenization). The following cells shows a review of this process.

# %%
# Getting the train set
train_data = imdb_plaintext['train']

# Initializing sentences list
training_sentences = []

# Loopping over all training examples and save to the list
for s,_ in train_data:
  training_sentences.append(s.numpy().decode('utf8'))

# %%
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

vocab_size = 10000
oov_tok = '<OOV>'

# Initializing the Tokenizer class
tokenizer_plaintext = Tokenizer(num_words = 10000, oov_token=oov_tok)

# Generating the word index dictionary for the training sentences
tokenizer_plaintext.fit_on_texts(training_sentences)

# Generating the training sequences
sequences = tokenizer_plaintext.texts_to_sequences(training_sentences)

# %% [markdown]
# The cell above uses a `vocab_size` of 10000 but it's easy to find OOV tokens when decoding using the lookup dictionary it created.

# %%
# Decoding the first sequence using the Tokenizer class
tokenizer_plaintext.sequences_to_texts(sequences[0:1])
# Out:
# ["this was an absolutely terrible movie don't be <OOV> in by christopher walken or michael <OOV> both are great actors but this must simply be their worst role in history even their great acting could not redeem this movie's ridiculous storyline this movie is an early nineties us propaganda piece the most pathetic scenes were those when the <OOV> rebels were making their cases for <OOV> maria <OOV> <OOV> appeared phony and her pseudo love affair with walken was nothing but a pathetic emotional plug in a movie that was devoid of any real meaning i am disappointed that there are movies like this ruining actor's like christopher <OOV> good name i could barely sit through it"]

# %% [markdown]
# For binary classifiers, this might not have a big impact but we may have other applications that will benefit from avoiding OOV tokens when training the model (e.g. text generation). If we want the tokenizer above to not have OOVs, then the `vocab_size` will increase to more than 88k. This can slow down training and bloat the model size. The encoder also won't be robust when used on other datasets which may contain new words, thus resulting in OOVs again.

# %%
# Total number of words in the word index dictionary
len(tokenizer_plaintext.word_index)
# Out:
# 88583

# %% [markdown]
# *Subword text encoding* gets around this problem by using parts of the word to compose whole words. This makes it more flexible when it encounters uncommon words.

# %%
# Print the subwords
print(len(tokenizer_subwords.subwords))
# Out:
# 7928

# %% [markdown]
# If we'll use it on the previous plain text sentence, we'll see that it won't have any OOVs even if it has a smaller vocab size.

# %%
# Encoding the first plaintext sentence using the subword text encoder
tokenized_string = tokenizer_subwords.encode(training_sentences[0])
print(tokenized_string)

# Decoding the sequence
original_string = tokenizer_subwords.decode(tokenized_string)

# Printing the result
print (original_string)
# Out:
# [62, 18, 41, 604, 927, 65, 3, 644, 7968, 21, 35, 5096, 36, 11, 43, 2948, 5240, 102, 50, 681, 7862, 1244, 3, 3266, 29, 122, 640, 2, 26, 14, 279, 438, 35, 79, 349, 384, 11, 1991, 3, 492, 79, 122, 188, 117, 33, 4047, 4531, 14, 65, 7968, 8, 1819, 3947, 3, 62, 27, 9, 41, 577, 5044, 2629, 2552, 7193, 7961, 3642, 3, 19, 107, 3903, 225, 85, 198, 72, 1, 1512, 738, 2347, 102, 6245, 8, 85, 308, 79, 6936, 7961, 23, 4981, 8044, 3, 6429, 7961, 1141, 1335, 1848, 4848, 55, 3601, 4217, 8050, 2, 5, 59, 3831, 1484, 8040, 7974, 174, 5773, 22, 5240, 102, 18, 247, 26, 4, 3903, 1612, 3902, 291, 11, 4, 27, 13, 18, 4092, 4008, 7961, 6, 119, 213, 2774, 3, 12, 258, 2306, 13, 91, 29, 171, 52, 229, 2, 1245, 5790, 995, 7968, 8, 52, 2948, 5240, 8039, 7968, 8, 74, 1249, 3, 12, 117, 2438, 1369, 192, 39, 7975]
# ...

# %% [markdown]
# Subword encoding can even perform well on words that are not commonly found on movie reviews. The result when using the plain text tokenizer, as expected, it will show many OOVs:

# %%
# Defining sample sentence
sample_string = 'TensorFlow, from basics to mastery'

# Encoding using the plain text tokenizer
tokenized_string = tokenizer_plaintext.texts_to_sequences([sample_string])
print ('Tokenized string is {}'.format(tokenized_string))

# Decoding and printing the result
original_string = tokenizer_plaintext.sequences_to_texts(tokenized_string)
print ('The original string: {}'.format(original_string))
# Out:
# Tokenized string is [[1, 37, 1, 6, 1]]
# The original string: ['<OOV> from <OOV> to <OOV>']

# %% [markdown]
# Then compare to the subword text encoder:

# %%
# Encoding using the subword text encoder
tokenized_string = tokenizer_subwords.encode(sample_string)
print ('Tokenized string is {}'.format(tokenized_string))

# Decoding and printing the results
original_string = tokenizer_subwords.decode(tokenized_string)
print ('The original string: {}'.format(original_string))
# Out:
# Tokenized string is [6307, 2327, 4043, 2120, 2, 48, 4249, 4429, 7, 2652, 8050]
# The original string: TensorFlow, from basics to mastery

# %% [markdown]
# The sentence is correctly decoded. The downside is the token sequence is much longer. Instead of only 5 when using word-encoding, we ended up with 11 tokens instead. The mapping for this sentence is shown below:

# %%
# Showing token to subword mapping:
for ts in tokenized_string:
  print ('{} ----> {}'.format(ts, tokenizer_subwords.decode([ts])))
# Out:
# 6307 ----> Ten
# 2327 ----> sor
# 4043 ----> Fl
# 2120 ----> ow
# 2 ----> ,
# 48 ----> from
# 4249 ----> basi
# 4429 ----> cs
# 7 ----> to
# 2652 ----> master
# 8050 ----> y

# %% [markdown]
# ## Multiple LSTM
# Demonstration multiple layer LSTM model with enabling the return_sequences flag to True. An LSTM layer expects a sequence input so if the previous layer is also an LSTM, then it should output a sequence as well. The code cell below  demonstrates this flag in action. The output dimension is in 3 dimensions (batch_size, timesteps, features) when when return_sequences is True.

# %%
import tensorflow as tf
import numpy as np

# Hyperparameters
batch_size = 1
timesteps = 20
features = 16
lstm_dim = 8

print(f'batch_size: {batch_size}')
print(f'timesteps (sequence length): {timesteps}')
print(f'features (embedding size): {features}')
print(f'lstm output units: {lstm_dim}')

# Define array input with random values
random_input = np.random.rand(batch_size,timesteps,features)
print(f'shape of input array: {random_input.shape}')

# Define LSTM that returns a single output
lstm = tf.keras.layers.LSTM(lstm_dim)
result = lstm(random_input)
print(f'shape of lstm output(return_sequences=False): {result.shape}')

# Define LSTM that returns a sequence
lstm_rs = tf.keras.layers.LSTM(lstm_dim, return_sequences=True)
result = lstm_rs(random_input)
print(f'shape of lstm output(return_sequences=True): {result.shape}')
# Out:
# batch_size: 1
# timesteps (sequence length): 20
# features (embedding size): 16
# lstm output units: 8
# shape of input array: (1, 20, 16)
# shape of lstm output(return_sequences=False): (1, 8)
# shape of lstm output(return_sequences=True): (1, 20, 8)

# %% [markdown]
# ## Training the model
#
# I will now train this model using this pre-tokenized dataset. Since these are already saved as sequences, I can jump straight to making uniform sized arrays for the train and test sets. These are also saved as `tf.data.Dataset` type so you can use the [`padded_batch()`](https://www.tensorflow.org/api_docs/python/tf/data/Dataset#padded_batch) method to create batches and pad the arrays into a uniform size for training.

# %%
BUFFER_SIZE = 10000
BATCH_SIZE = 64

# Getting the train and testing splits
train_data, test_data = imdb_subwords['train'], imdb_subwords['test'],

# Shuffling the training data
train_dataset = train_data.shuffle(BUFFER_SIZE)

# Batching and padding the datasets to the maximum length of the sequences
train_dataset = train_dataset.padded_batch(BATCH_SIZE)
test_dataset = test_data.padded_batch(BATCH_SIZE)

# %% [markdown]
# Next, I will build the model:

# %%
import tensorflow as tf
# Hyperparameters
embedding_dim = 64
lstm1_dim = 64
lstm2_dim = 32
dense_dim = 64

# Defining dimensionality of the embedding
embedding_dim = 64

# Building the model
model = tf.keras.Sequential([
    tf.keras.layers.Embedding(tokenizer_subwords.vocab_size, embedding_dim),
    tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(lstm1_dim, return_sequences=True)),
    tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(lstm2_dim)),
    tf.keras.layers.Dense(dense_dim, activation='relu'),
    tf.keras.layers.Dense(1, activation='sigmoid')
])

# Printing the model summary
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  embedding (Embedding)       (None, None, 64)          523840
#
#  bidirectional (Bidirection  (None, None, 128)         66048
#  al)
#
#  bidirectional_1 (Bidirecti  (None, 64)                41216
#  onal)
#
#  dense (Dense)               (None, 64)                4160
#
#  dense_1 (Dense)             (None, 1)                 65
#
# ...
# Total params: 635329 (2.42 MB)
# Trainable params: 635329 (2.42 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
num_epochs = 20

# Setting the training parameters
model.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])

# Starting training
history = model.fit(train_dataset, epochs=num_epochs, validation_data=test_dataset)
# Out:
# Epoch 1/20
# 391/391 [==============================] - 156s 375ms/step - loss: 0.2720 - accuracy: 0.8966 - val_loss: 0.4842 - val_accuracy: 0.8101
# Epoch 2/20
# 391/391 [==============================] - 108s 276ms/step - loss: 0.1891 - accuracy: 0.9308 - val_loss: 0.4323 - val_accuracy: 0.8446
# Epoch 3/20
# 391/391 [==============================] - 102s 259ms/step - loss: 0.1260 - accuracy: 0.9598 - val_loss: 0.4282 - val_accuracy: 0.8595
# Epoch 4/20
# 391/391 [==============================] - 94s 239ms/step - loss: 0.0852 - accuracy: 0.9746 - val_loss: 0.4842 - val_accuracy: 0.8571
# Epoch 5/20
# 391/391 [==============================] - 90s 229ms/step - loss: 0.0625 - accuracy: 0.9826 - val_loss: 0.5329 - val_accuracy: 0.8516
# Epoch 6/20
# 391/391 [==============================] - 86s 219ms/step - loss: 0.0512 - accuracy: 0.9861 - val_loss: 0.5843 - val_accuracy: 0.8498
# Epoch 7/20
# ...

# %% [markdown]
# ## Visualizing the results
#
# I use the cell below to plot the training results.

# %%
import matplotlib.pyplot as plt

# Plotting utility
def plot_graphs(history, string):
  plt.plot(history.history[string])
  plt.plot(history.history['val_'+string])
  plt.xlabel("Epochs")
  plt.ylabel(string)
  plt.legend([string, 'val_'+string])
  plt.show()

# Plotting the accuracy and results
plot_graphs(history, "accuracy")
plot_graphs(history, "loss")

# %% [markdown]
# ## Wrap Up
#
# In this project, I saw how subword text encoding can be a robust technique to avoid out-of-vocabulary tokens. It can decode uncommon words it hasn't seen before even with a relatively small vocab size. Consequently, it results in longer token sequences when compared to full word tokenization. Next week, I will look at other architectures that can be used when building classifier. These will be recurrent neural networks and convolutional neural networks.

# %%
print(tokenizer_subwords.subwords)
# Out:
# ['the_', ', ', '. ', 'a_', 'and_', 'of_', 'to_', 's_', 'is_', 'br', 'in_', 'I_', 'that_', 'this_', 'it_', ' /><', ' />', 'was_', 'The_', 'as_', 't_', 'with_', 'for_', '.<', 'on_', 'but_', 'movie_', ' (', 'are_', 'his_', 'have_', 'film_', 'not_', 'ing_', 'be_', 'ed_', 'you_', ' "', 'it', 'd_', 'an_', 'he_', 'by_', 'at_', 'one_', 'who_', 'y_', 'from_', 'e_', 'or_', 'all_', 'like_', 'they_', '" ', 'so_', 'just_', 'has_', ') ', 'her_', 'about_', 'out_', 'This_', 'some_', 'ly_', 'movie', 'film', 'very_', 'more_', 'It_', 'would_', 'what_', 'when_', 'which_', 'good_', 'if_', 'up_', 'only_', 'even_', 'their_', 'had_', 'really_', 'my_', 'can_', 'no_', 'were_', 'see_', 'she_', '? ', 'than_', '! ', 'there_', 'get_', 'been_', 'into_', ' - ', 'will_', 'much_', 'story_', 'because_', 'ing', 'time_', 'n_', 'we_', 'ed', 'me_', ': ', 'most_', 'other_', 'don', 'do_', 'm_', 'es_', 'how_', 'also_', 'make_', 'its_', 'could_', 'first_', 'any_', "' ", 'people_', 'great_', 've_', 'ly', 'er_', 'made_', 'r_', 
# ...
